# %%
import json
import requests
import pandas as pd

url = "http://data1.library.sh.cn/shnh/gmwx/webapi/architecture/getArchitectures"
querystring = {"isRed":"3","key":"3f5df65840c93fea3c1026b8a64649dffa3d6328"}
response = requests.request('GET', url, params=querystring)
json_data = response.json()
json_data
# Out:
# {'result': '0',
#  'data': [{'nameE': 'chongyuanbieshu',
#    'address': '常熟路183弄',
#    'houseNumber': '',
#    'placeUri': 'http://data.library.sh.cn/entity/place/gbjiu33e2bbxy6t4',
#    'firstImg': '',
#    'type': '上海市优秀历史建筑',
#    'uri': 'http://data.library.sh.cn/entity/architecture/0bh8czukwwdz773w',
#    'long': '121.45559',
#    'nameT': '崇源別墅',
#    'nameS': '崇源别墅',
#    'des': '',
#    'road': '常熟路',
#    'roadUri': 'http://data.library.sh.cn/entity/road/yo0bpc6rbslkzh1k',
#    'lat': '31.221166',
#    'placeValue': '徐汇'},
#   {'nameE': 'zhuzhai',
#    'address': '南昌路212、244弄',
#    'houseNumber': '',
#    'placeUri': 'http://data.library.sh.cn/entity/place/r4tibjuyc0ta5p75',
#    'firstImg': '',
#    'type': '上海市优秀历史建筑',
#    'uri': 'http://data.library.sh.cn/entity/architecture/06w7n6cjlkuypjsx',
#    'long': '121.46869',
#    'nameT': '住宅',
#    'nameS': '住宅',
#    'des': '',
#    'road': '南昌路',
#    'roadUri': 'http://data.library.sh.cn/entity/road/6c14oyljkwgk73zq',
# ...

# %%
pageth = 2
querystring = {"isRed":"3","key":"3f5df65840c93fea3c1026b8a64649dffa3d6328", "pageth": "2"}
response = requests.request('GET', url, params=querystring)
json_data = response.json()
json_data
# Out:
# {'result': '0',
#  'data': [{'nameE': 'xinhuayinranchang/juminlou',
#    'address': '榆林路43号、47号、59号、63号大宅',
#    'houseNumber': '43号、47号、59号、63号',
#    'placeUri': 'http://data.library.sh.cn/entity/place/c8uwnyqxg3qq28r3',
#    'firstImg': '',
#    'type': '上海市优秀历史建筑',
#    'uri': 'http://data.library.sh.cn/entity/architecture/0dahi7c42nkyzyc4',
#    'long': '121.52109',
#    'nameT': '新華印染廠/居民樓',
#    'nameS': '新华印染厂/居民楼',
#    'des': '',
#    'road': '',
#    'roadUri': '',
#    'lat': '31.258865',
#    'placeValue': '虹口'},
#   {'nameE': 'qixiacun',
#    'address': '徐汇区五原路372弄6-9号',
#    'houseNumber': '6-9号',
#    'placeUri': 'http://data.library.sh.cn/entity/place/gbjiu33e2bbxy6t4',
#    'firstImg': '',
#    'type': '上海市优秀历史建筑',
#    'uri': 'http://data.library.sh.cn/entity/architecture/0mpbe54b4fmad0e2',
#    'long': '121.44823',
#    'nameT': '棲霞村',
#    'nameS': '栖霞村',
#    'des': '',
#    'road': '五原路',
# ...

# %%
import json
import requests
import pandas as pd

road_url = "http://data1.library.sh.cn/shnh/wkl/webapi/building/list"
road_querystring = {"type":"2","key":"3f5df65840c93fea3c1026b8a64649dffa3d6328"}
road_response = requests.request('GET', road_url, params=road_querystring)
road_json_data = road_response.json()
road_json_data
# Out:
# {'result': '0',
#  'data': [{'address': '华山路849号',
#    'created': '1862',
#    'name': '丁香花园',
#    'houseNumber': '849号',
#    'architectureStructure': '3幢西式花园别墅，占地面积2.67万平方米，总建筑面积2934平方米，砖木结构',
#    'uri': 'http://data.library.sh.cn/entity/architecture/sm4repfu8n3ga66j',
#    'architecturalStyle': '英国乡村建筑花园别墅，中国传统南方园林'},
#   {'address': '武康路390号',
#    'created': '1932',
#    'houseNumber': '390号',
#    'description': '武康路390号是一幢造型别致、建造精美的花园洋房，由意大利总领事馆府邸委托义品地产公司建造，主人是意大利总领事尼隆。建筑占地面积约300平方米，二层砖木石混合结构，建筑面积612平方米，平面大致呈正方形。底层的东南西三面均设计为敞廊，主立面的中间设计为稍外凸的三开间半圆拱廊，中间为窗，两侧为通道。屋顶为欧洲建筑常见的四坡红瓦顶，在主立面的中轴线屋顶处，设计有白色的石结构阳台，阳台内侧是假二层的房间，房间天花板是流畅的弧顶。从建筑外观看，白墙与红瓦搭配合理，色彩对比强烈。三面使用柱子支撑的敞廊有点像中国四面来风的亭子。1945年抗战胜利后，南京国民政府不承认意大利与汪伪政府的外交关系，意大利总领事馆实际上结束了它的使命，该处产业被中国政府收回。',
#    'designer': [{'label': '义品地产公司',
#      'uri': 'http://data.library.sh.cn/entity/organization/jcy1zak6iq2e4vfg'}],
#    'uri': 'http://data.library.sh.cn/entity/architecture/fcryfptin8zm6qe4',
#    'architecturalStyle': '地中海式',
# ...

# %%
movie_detail_url = "http://data1.library.sh.cn/shnh/dydata/webapi/movie/movieDetail?uri=http://data.library.sh.cn/dy/resource/movie/612x1xoyxtzxuvaf&key=3f5df65840c93fea3c1026b8a64649dffa3d6328"
movie_detail_response = requests.request('GET', movie_detail_url)
movie_detail_json_data = response.json()
movie_detail_json_data
# Out:
# {'result': '0',
#  'data': [{'nameE': 'xinhuayinranchang/juminlou',
#    'address': '榆林路43号、47号、59号、63号大宅',
#    'houseNumber': '43号、47号、59号、63号',
#    'placeUri': 'http://data.library.sh.cn/entity/place/c8uwnyqxg3qq28r3',
#    'firstImg': '',
#    'type': '上海市优秀历史建筑',
#    'uri': 'http://data.library.sh.cn/entity/architecture/0dahi7c42nkyzyc4',
#    'long': '121.52109',
#    'nameT': '新華印染廠/居民樓',
#    'nameS': '新华印染厂/居民楼',
#    'des': '',
#    'road': '',
#    'roadUri': '',
#    'lat': '31.258865',
#    'placeValue': '虹口'},
#   {'nameE': 'qixiacun',
#    'address': '徐汇区五原路372弄6-9号',
#    'houseNumber': '6-9号',
#    'placeUri': 'http://data.library.sh.cn/entity/place/gbjiu33e2bbxy6t4',
#    'firstImg': '',
#    'type': '上海市优秀历史建筑',
#    'uri': 'http://data.library.sh.cn/entity/architecture/0mpbe54b4fmad0e2',
#    'long': '121.44823',
#    'nameT': '棲霞村',
#    'nameS': '栖霞村',
#    'des': '',
#    'road': '五原路',
# ...
